# %%
import numpy as np
import pandas as pd

# %%
beer = pd.read_csv('beer_reviews.csv')
beer
# Out:
#          brewery_id                 brewery_name  review_time  review_overall  \
# 0             10325              Vecchio Birraio   1234817823             1.5
# 1             10325              Vecchio Birraio   1235915097             3.0
# 2             10325              Vecchio Birraio   1235916604             3.0
# 3             10325              Vecchio Birraio   1234725145             3.0
# 4              1075      Caldera Brewing Company   1293735206             4.0
# ...             ...                          ...          ...             ...
# 1586609       14359  The Defiant Brewing Company   1162684892             5.0
# 1586610       14359  The Defiant Brewing Company   1161048566             4.0
# 1586611       14359  The Defiant Brewing Company   1160702513             4.5
# 1586612       14359  The Defiant Brewing Company   1160023044             4.0
# 1586613       14359  The Defiant Brewing Company   1160005319             5.0
#
# ...

# %%
beer.isnull().sum()
# Out:
# brewery_id                0
# brewery_name             15
# review_time               0
# review_overall            0
# review_aroma              0
# review_appearance         0
# review_profilename      348
# beer_style                0
# review_palate             0
# review_taste              0
# beer_name                 0
# beer_abv              67785
# beer_beerid               0
# dtype: int64

# %%
beer.dropna(subset=['beer_abv','brewery_name','review_profilename'],inplace = True)
beer.to_csv('beer_reviews_updated.csv',index = False)

# %%
beerUpdated = pd.read_csv('beer_reviews_updated.csv')
beerUpdated
# Out:
#          brewery_id                 brewery_name  review_time  review_overall  \
# 0             10325              Vecchio Birraio   1234817823             1.5
# 1             10325              Vecchio Birraio   1235915097             3.0
# 2             10325              Vecchio Birraio   1235916604             3.0
# 3             10325              Vecchio Birraio   1234725145             3.0
# 4              1075      Caldera Brewing Company   1293735206             4.0
# ...             ...                          ...          ...             ...
# 1518473       14359  The Defiant Brewing Company   1162684892             5.0
# 1518474       14359  The Defiant Brewing Company   1161048566             4.0
# 1518475       14359  The Defiant Brewing Company   1160702513             4.5
# 1518476       14359  The Defiant Brewing Company   1160023044             4.0
# 1518477       14359  The Defiant Brewing Company   1160005319             5.0
#
# ...

# %%
beerUpdated['beer_abv'].isnull().sum()
# Out:
# 0

# %%
beerUpdated['beer_abv'].notnull().sum()
# Out:
# 1518478

# %%
beerUpdated.isnull().sum()
# Out:
# brewery_id            0
# brewery_name          0
# review_time           0
# review_overall        0
# review_aroma          0
# review_appearance     0
# review_profilename    0
# beer_style            0
# review_palate         0
# review_taste          0
# beer_name             0
# beer_abv              0
# beer_beerid           0
# dtype: int64

# %% [markdown]
# ## Correlation matrix as heatmap

# %%
from matplotlib import pyplot as plt
import seaborn as sns

sns.set_theme(style="white")
corr = beerUpdated.corr()
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(250, 10, as_cmap=True)
sns.heatmap(corr, annot=True, cmap=cmap, vmin=-1, vmax=1)
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5]),
#  [Text(0.5, 0, 'brewery_id'),
#   Text(1.5, 0, 'review_time'),
#   Text(2.5, 0, 'review_overall'),
#   Text(3.5, 0, 'review_aroma'),
#   Text(4.5, 0, 'review_appearance'),
#   Text(5.5, 0, 'review_palate'),
#   Text(6.5, 0, 'review_taste'),
#   Text(7.5, 0, 'beer_abv'),
#   Text(8.5, 0, 'beer_beerid')])
