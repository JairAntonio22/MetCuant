# %%
import numpy as np
import pandas as pd
import fitter as ft
import datetime

# %%
start = datetime.datetime.now()
beer = pd.read_csv('beer_reviews_updated.csv')
beer
# Out:
#          brewery_id                 brewery_name  review_time  review_overall  \
# 0             10325              Vecchio Birraio   1234817823             1.5
# 1             10325              Vecchio Birraio   1235915097             3.0
# 2             10325              Vecchio Birraio   1235916604             3.0
# 3             10325              Vecchio Birraio   1234725145             3.0
# 4              1075      Caldera Brewing Company   1293735206             4.0
# ...             ...                          ...          ...             ...
# 1518473       14359  The Defiant Brewing Company   1162684892             5.0
# 1518474       14359  The Defiant Brewing Company   1161048566             4.0
# 1518475       14359  The Defiant Brewing Company   1160702513             4.5
# 1518476       14359  The Defiant Brewing Company   1160023044             4.0
# 1518477       14359  The Defiant Brewing Company   1160005319             5.0
#
# ...

# %%
def fitDistribution(df,colname):
    var = df[colname].values
    dist = ft.Fitter(var)
    dist.fit()
    return dist

# %%
#review_overall
ro = fitDistribution(beer,'review_overall')
ro.summary()
# Out:
# WARNING:root:SKIPPED beta distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED argus distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED alpha distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED bradford distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED burr distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED arcsine distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED betaprime distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED burr12 distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED chi distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED chi2 distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED cosine distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED crystalball distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED dgamma distribution (taking more than 30 seconds)
# ...

# %%
#review_aroma
rar = fitDistribution(beer,'review_aroma')
rar.summary()
# Out:
# WARNING:root:SKIPPED anglit distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED arcsine distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED beta distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED bradford distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED betaprime distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED alpha distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED burr distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED argus distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED burr12 distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED cauchy distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED chi distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED crystalball distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED cosine distribution (taking more than 30 seconds)
# ...

# %%
#review_appearance
rapp = fitDistribution(beer,'review_appearance')
rapp.summary()
# Out:
# WARNING:root:SKIPPED alpha distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED beta distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED bradford distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED betaprime distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED argus distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED anglit distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED burr distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED arcsine distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED burr12 distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED cauchy distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED chi distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED chi2 distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED cosine distribution (taking more than 30 seconds)
# ...

# %%
#review_palate
rapa = fitDistribution(beer,'review_palate')
rapa.summary()
# Out:
# WARNING:root:SKIPPED alpha distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED anglit distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED arcsine distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED argus distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED beta distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED burr distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED betaprime distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED bradford distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED burr12 distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED cauchy distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED chi distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED chi2 distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED crystalball distribution (taking more than 30 seconds)
# ...

# %%
#review_taste
rt = fitDistribution(beer,'review_taste')
rt.summary()
# Out:
# WARNING:root:SKIPPED alpha distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED arcsine distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED anglit distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED betaprime distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED argus distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED beta distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED burr distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED bradford distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED chi distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED cauchy distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED burr12 distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED dweibull distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED cosine distribution (taking more than 30 seconds)
# ...

# %%
#beer_abv
ba = fitDistribution(beer,'beer_abv')
ba.summary()
# Out:
# C:\Users\Bernardo\anaconda3\lib\site-packages\scipy\integrate\quadpack.py:879: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# WARNING:root:SKIPPED alpha distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED bradford distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED argus distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED arcsine distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED burr distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED beta distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED betaprime distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED anglit distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED burr12 distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED chi distribution (taking more than 30 seconds)
# ...

# %%
end = datetime.datetime.now()
print("The program lasted: {} to execute".format(end-start))
# Out:
# The program lasted: 4:05:45.031860 to execute

# %%
#review_overall best method
ro.get_best()
# Out:
# C:\Users\Bernardo\anaconda3\lib\site-packages\scipy\integrate\quadpack.py:879: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# {'laplace': {'loc': 4.0, 'scale': 0.5002667144337949}}

# %%
#review_aroma best method
rar.get_best()
# Out:
# {'laplace': {'loc': 4.0, 'scale': 0.5111917986299439}}

# %%
#review_appearance best method
rapp.get_best()
# Out:
# {'laplace': {'loc': 4.0, 'scale': 0.4194983397849689}}

# %%
#review_palate best method
rapa.get_best()
# Out:
# {'laplace': {'loc': 4.0, 'scale': 0.4893370203585432}}

# %%
#review_taste best method
rt.get_best()
# Out:
# {'laplace': {'loc': 4.0, 'scale': 0.520368421537882}}

# %%
#beer_abv best method
ba.get_best()
# Out:
# {'norm': {'loc': 7.042488188831184, 'scale': 2.32256723734782}}
